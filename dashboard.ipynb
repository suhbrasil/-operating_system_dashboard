# %%
import pandas as pd
import numpy as np
import panel as pn
from process import *
pn.extension('tabulator')

import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='307c3902-02aa-451d-90c8-d23d69065e12'>
#   <div id="c6f5590d-7806-429d-882d-4bc135e1b109" data-root-id="307c3902-02aa-451d-90c8-d23d69065e12" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
df = pd.DataFrame([monitor_processes()])
print(monitor_processes())
# Out:
# {'Nome': 'kworker/0:1-events', 'Threads': 'I (idle)', 'Usuário': '0\t0\t0\t0', 'Estado': 'I (idle)', 'PID': 53026}

# %%
df_pane = pn.pane.DataFrame(df, width=400)
df_pane
# Out:
# DataFrame(DataFrame, width=400)

# %%
template = pn.template.EditableTemplate(
    editable=True,
    title='Dashboard',
    sidebar=df_pane,
    meta_refresh="5",
)
template.servable();
